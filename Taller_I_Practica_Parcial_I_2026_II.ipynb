# %% [markdown]
# <a href="https://colab.research.google.com/github/s4mram4y4/py_CS/blob/main/Taller_I_Practica_Parcial_I_2026_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Taller Parcial I**
#
# Introducción a las Ciencias de la Computación y a la Programación
#
# Fecha Parcial: 22 de septiembre 2026

# %% [markdown]
# **IMPORTANTE !! :** Recuerde que:
#
# 1. En los algoritmos que diseñe para el parcial, únicamente se permite el uso de los comandos presentes en las Notas de Clase compartidas al iniciar el semestre.
#
# 2. Para la evaluación del parcial, cualquier ejercicio resuelto con comandos distintos a los permitidos, se calificará con cero.
#
# 3. El parcial debe presentarse en la plataforma Colab Google. Pratique realizando una copia de este taller en esta plataforma.

# %% [markdown]
# #Ejercicio 1:
#
# Construya un programa que permita introducir por vía teclado un párrafo y una palabra. El programa debe determinar cuantas veces la palabra se repite en el párrafo.

# %% [markdown]
# #Ejercicio 2:
#
# Cree un programa para ingresar un párrafo por teclado que permita extraer un fragmento del texto ingresado. El usuario seleccionará dicho fragmento introduciendo el índice de inicio de la primera palabra y el índice final de la última palabra del fragmento.

# %% [markdown]
# ## Ejercicio 3:
#
# Diseñe un algoritmo que pinte usando asteriscos $*$, un rombo tal que una de sus diagonales tengan una cantidad de asteriscos ($*$) igual a un valor entero dado por el usuario.
# Por ejemplo, si el valor de la diagonal es 10, entonces el rombo debe verse como sigue:
#
#                 *
#                * *
#               * * *
#              * * * *
#             * * * * *
#            * * * * * *
#           * * * * * * *
#          * * * * * * * *
#         * * * * * * * * *
#        * * * * * * * * * *
#         * * * * * * * * *
#          * * * * * * * *
#            * * * * * *
#             * * * * *
#              * * * *
#               * * *
#                * *
#                 *
#
# **Nota :** Deben tener en cuenta que no pueden usar comandos que no estèn en las notas de clase, (p.ej. print("*" * 10)  # Salida: **********) **no se puede** usar caracter por entero este comando no està en las notas de clase. Lo pueden usar siempre y cuando lo definan como una funciòn en tèrminos de un ciclo for y un print.

# %% [markdown]
# # Ejercicio 4
#
# Diseñe un programa que permita al usuario crear una lista con la cantidad de palabras que desee, ingresadas en minúsculas y sin acentos. El programa debe retornar las palabras de la lista que tengan una longitud mínima de 5 caracteres o que contengan al menos tres vocales (sean iguales o diferentes).

# %% [markdown]
# # Ejercicio 5
#
# Diseñe un algoritmo que solicite al usuario dos oraciones y, tras compararlas, devuelva la lista de palabras comunes en ambas.

# %% [markdown]
# # Ejercicio 6 **Sistema de registro académico**
#
# Diseñe un programa que permita registrar estudiantes y gestionar sus calificaciones mediante una estructura de datos adecuada. Para cada estudiante se debe almacenar la siguiente información:
#
# Nombre.
#
# Código estudiantil.
#
# Lista de calificaciones.
#
# El programa debe permitir realizar las siguientes operaciones:
#
# Registrar un estudiante nuevo, inicialmente sin calificaciones.
#
# Añadir una calificación a un estudiante, utilizando su código para identificarlo.
#
# Consultar el promedio de calificaciones de un estudiante.
#
# Identificar al estudiante con el promedio más alto y mostrar su nombre junto con dicho promedio.
#
# La interacción con el usuario debe realizarse mediante un menú sencillo con opciones como:
#
# * Agregar estudiante.
#
# * Agregar calificación.
#
# * Consultar promedio.
#
# * Consultar el estudiante con mejor rendimiento.
#
# * Mostrar todos los estudiantes.
#
# * Salir.
#
# El programa debe ejecutarse continuamente hasta que el usuario seleccione la opción Salir. La información de los estudiantes debe organizarse utilizando diccionarios y listas.

# %% [markdown]
# ## Ejercicio 7.
#
# Diseñe un programa que reciba una lista de números naturales y calcule, para cada uno de ellos, el promedio de los dígitos que lo conforman, dichos promedios deben quedar sobre una lista.

# %% [markdown]
# ## Ejercicio 8. **Analizador de Textos y Palabras (Manipulación de Strings y Listas)**
#
# Diseñe un programa que solicite al usuario ingresar un párrafo de texto para ser analizado. A partir de ese texto, el sistema debe desplegar un menú que permita realizar las siguientes acciones:
#
# * Contar palabras por longitud: Solicita al usuario un número entero N y muestra cuántas palabras del párrafo tienen una longitud exacta de N caracteres.
#
# * Buscar palabra: Pide una palabra al usuario y determina si se encuentra en el párrafo, indicando cuántas veces aparece (sin importar mayúsculas o minúsculas).
#
# * Reemplazar texto: Solicita una palabra del párrafo y el término por el cual se desea sustituir. El programa debe mostrar el párrafo con la modificación realizada.
#
# * Palabras que inician con vocal: Muestra una lista con todas las palabras únicas del párrafo que comiencen con una vocal.
#
# * Salir.

# %% [markdown]
# ## Ejercicio 9. **Bitácora de Viajes (Diccionarios y Operaciones Lógicas)**
#
# Diseñe un programa que funcione como una bitácora digital de los viajes realizados por un usuario. El sistema utilizará un diccionario donde cada clave será el nombre de un país visitado, y su valor será una lista con las ciudades que conoció en ese país.El menú interactivo debe ofrecer las siguientes opciones:
#
# * Registrar visita: Pide el nombre del país y la ciudad visitada. Si el país ya estaba registrado, añade la ciudad a su lista sin duplicarla.
#
# * Buscar país: Pide el nombre de un país y muestra todas las ciudades registradas allí. Si no existe, indica que no ha sido visitado.
#
# * País más explorado: Determina y muestra el nombre del país en el que el usuario ha visitado la mayor cantidad de ciudades diferentes.
#
# * Total de ciudades: Calcula el número total de ciudades distintas que el usuario ha registrado a lo largo de toda su bitácora.
#
# * Salir.
